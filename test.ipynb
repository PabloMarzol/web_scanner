# %%
# Out:
# New Cumulative Cost (LQR) = 1.1
# New Cumulative Cost (QL) = 2626040738661128.0
# New Cumulative Cost (QLϵ-0.1) = 3609882581777917.5
# C:\Users\pablo\AppData\Local\Temp\ipykernel_38068\3036372634.py:46: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(np.round(cost,1))
# C:\Users\pablo\AppData\Local\Temp\ipykernel_38068\3036372634.py:69: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   return float(np.round(cost,1))
